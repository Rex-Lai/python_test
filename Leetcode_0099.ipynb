# %%
def swap(arr):
    #dict
    arr_dict = {}
    for str in arr:
        arr_dict.update({str:0})
    if len(arr[0]) <= 2:
        return len(arr_dict.keys())
    for str in arr:
        new_str = list(str)
        size = len(new_str)
        for i in range(size):
            for j in range(size):
                if i % 2 == j % 2:
                    tmp = new_str[i]
                    new_str[i] = new_str[j]
                    new_str[j] = tmp
            key = ''.join(new_str)
            if key == str:
                continue
            print(str, key)
            if key in arr_dict.keys():
                print key
                val = arr_dict[key] + 1
                arr_dict.update({key:val})
        print('+'*10)
    return arr_dict
array = []
array.append(['aa','ab','bb','ba'])
array.append(['a','b','c','a','c','c'])
array.append(['abc','acb','bac','bca','cab','cba'])
array.append(['abcd','cdab','adcb','cbad'])

for aa in array:
    print aa
    print(swap(aa))
# Out:
# ['aa', 'ab', 'bb', 'ba']
# 4
# ['a', 'b', 'c', 'a', 'c', 'c']
# 3
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
# ('abc', 'cba')
# cba
# ('abc', 'cba')
# cba
# ++++++++++
# ('acb', 'bca')
# bca
# ('acb', 'bca')
# bca
# ++++++++++
# ('bac', 'cab')
# cab
# ('bac', 'cab')
# cab
# ++++++++++
# ('bca', 'acb')
# acb
# ('bca', 'acb')
# acb
# ++++++++++
# ('cab', 'bac')
# bac
# ('cab', 'bac')
# bac
# ++++++++++
# ('cba', 'abc')
# abc
# ('cba', 'abc')
# abc
# ++++++++++
# {'acb': 2, 'abc': 2, 'bac': 2, 'cab': 2, 'cba': 2, 'bca': 2}
# ['abcd', 'cdab', 'adcb', 'cbad']
# ('abcd', 'cbad')
# cbad
# ('abcd', 'cdab')
# cdab
# ('abcd', 'adcb')
# adcb
# ++++++++++
# ('cdab', 'adcb')
# adcb
# ('cdab', 'abcd')
# abcd
# ('cdab', 'cbad')
# cbad
# ++++++++++
# ('adcb', 'cdab')
# cdab
# ('adcb', 'cbad')
# cbad
# ('adcb', 'abcd')
# abcd
# ++++++++++
# ('cbad', 'abcd')
# abcd
# ('cbad', 'adcb')
# adcb
# ('cbad', 'cdab')
# cdab
# ++++++++++
# {'abcd': 3, 'adcb': 3, 'cdab': 3, 'cbad': 3}
